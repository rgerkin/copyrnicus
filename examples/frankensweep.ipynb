# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
import math
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(font_scale=1.5)
import copernicus as cop
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cop.DATA = cop.DATA_ROOT / 'ExportedDorsoventralData'
assert cop.DATA.exists()

# %%
recordings = cop.get_recordings()
"There are %d sets of recordings." % len(recordings)
# Out:
# 'There are 30 sets of recordings.'

# %%
fsweeps = cop.get_frankensweeps(12, recordings=recordings, protocols=['Depolarize', 'Hyperpolarize'])

# %%
cop.plot_frankensweeps(fsweeps)

# %%
cop.write_frankensweeps(fsweeps, 'Franken001')
